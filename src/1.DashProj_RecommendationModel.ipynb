# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity
import warnings

# Settings the warnings to be ignored
warnings.filterwarnings('ignore')

# %%
spotify_data = pd.read_csv('spotify-2023.csv', encoding='ISO-8859-1')

# %%
spotify_data.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# 0                147  141381703                  43  ...  125   B  Major
# 1                 48  133716286                  48  ...   92  C#  Major
# 2                113  140003974                  94  ...  138   F  Major
# 3                100  800840817                 116  ...  170   A  Major
# 4                 50  303236322                  84  ...  144   A  Minor
#
#   danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 0             80         89       83             31                   0
# 1             71         61       74              7                   0
# 2             51         32       53             17                   0
# 3             55         58       72             11                   0
# 4             65         23       80             14                  63
#
#    liveness_%  speechiness_%
# 0           8              4
# 1          10              4
# 2          31              6
# 3          11             15
# 4          11              6
#
# [5 rows x 24 columns]

# %%
spotify_data.duplicated().sum()
# Out:
# 0

# %%
# Extract the audio features for the recommendation
recommendation_features = ['bpm', 'danceability_%', 'valence_%', 'energy_%', 'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%']

# %%
spotify_data[recommendation_features].head()
# Out:
#    bpm  danceability_%  valence_%  energy_%  acousticness_%  \
# 0  125              80         89        83              31
# 1   92              71         61        74               7
# 2  138              51         32        53              17
# 3  170              55         58        72              11
# 4  144              65         23        80              14
#
#    instrumentalness_%  liveness_%  speechiness_%
# 0                   0           8              4
# 1                   0          10              4
# 2                   0          31              6
# 3                   0          11             15
# 4                  63          11              6

# %%
# Normalize the features
scaler = MinMaxScaler()
normalized_features = scaler.fit_transform(spotify_data[recommendation_features])

# Convert normalized features back to a DataFrame for easier handling
normalized_df = pd.DataFrame(normalized_features, columns=recommendation_features)
normalized_df.head()
# Out:
#         bpm  danceability_%  valence_%  energy_%  acousticness_%  \
# 0  0.425532        0.780822   0.913978  0.840909        0.319588
# 1  0.191489        0.657534   0.612903  0.738636        0.072165
# 2  0.517730        0.383562   0.301075  0.500000        0.175258
# 3  0.744681        0.438356   0.580645  0.715909        0.113402
# 4  0.560284        0.575342   0.204301  0.806818        0.144330
#
#    instrumentalness_%  liveness_%  speechiness_%
# 0            0.000000    0.053191       0.032258
# 1            0.000000    0.074468       0.032258
# 2            0.000000    0.297872       0.064516
# 3            0.000000    0.085106       0.209677
# 4            0.692308    0.085106       0.064516

# %% [markdown]
# ### Content-Based Recomendation

# %% [markdown]
# #### Cosine Similarity

# %%
# Compute the cosine similarity matrix
similarity_matrix = cosine_similarity(normalized_df)

# Convert the similarity matrix to a DataFrame for better readability and handling
similarity_df = pd.DataFrame(similarity_matrix, index=spotify_data['track_name'], columns=spotify_data['track_name'])
similarity_df.head()
# Out:
# track_name                           Seven (feat. Latto) (Explicit Ver.)  \
# track_name
# Seven (feat. Latto) (Explicit Ver.)                             1.000000
# LALA                                                            0.975647
# vampire                                                         0.880344
# Cruel Summer                                                    0.913981
# WHERE SHE GOES                                                  0.755991
#
# track_name                               LALA   vampire  Cruel Summer  \
# track_name
# Seven (feat. Latto) (Explicit Ver.)  0.975647  0.880344      0.913981
# LALA                                 1.000000  0.848438      0.876134
# vampire                              0.848438  1.000000      0.947706
# Cruel Summer                         0.876134  0.947706      1.000000
# WHERE SHE GOES                       0.761163  0.808084      0.800570
#
# track_name                           WHERE SHE GOES  Sprinter  \
# track_name
# Seven (feat. Latto) (Explicit Ver.)        0.755991  0.936269
# LALA                                       0.761163  0.916185
# vampire                                    0.808084  0.877307
# Cruel Summer                               0.800570  0.910577
# WHERE SHE GOES                             1.000000  0.753580
#
# track_name                           Ella Baila Sola  Columbia  fukumean  \
# track_name
# Seven (feat. Latto) (Explicit Ver.)         0.979482  0.910542  0.855850
# LALA                                        0.917155  0.908580  0.876697
# vampire                                     0.905297  0.879835  0.919387
# Cruel Summer                                0.931923  0.837759  0.855452
# WHERE SHE GOES                              0.754172  0.806952  0.811049
#
# track_name                           La Bebe - Remix  ...  Privileged Rappers  \
# track_name                                            ...
# Seven (feat. Latto) (Explicit Ver.)         0.865533  ...            0.921663
# LALA                                        0.819718  ...            0.924463
# vampire                                     0.880600  ...            0.881834
# Cruel Summer                                0.922431  ...            0.913622
# WHERE SHE GOES                              0.736370  ...            0.765912
#
# track_name                           The Astronaut  BackOutsideBoyz  \
# track_name
# Seven (feat. Latto) (Explicit Ver.)       0.858991         0.796932
# LALA                                      0.890907         0.798221
# vampire                                   0.918433         0.875415
# Cruel Summer                              0.914379         0.844334
# WHERE SHE GOES                            0.847082         0.707696
#
# track_name                           Broke Boys  The Great War  My Mind & Me  \
# track_name
# Seven (feat. Latto) (Explicit Ver.)    0.741030       0.981515      0.805591
# LALA                                   0.775496       0.978372      0.707324
# vampire                                0.865885       0.873215      0.860803
# Cruel Summer                           0.835299       0.899534      0.808021
# WHERE SHE GOES                         0.764178       0.775037      0.717606
#
# track_name                           Bigger Than The Whole Sky  \
# track_name
# Seven (feat. Latto) (Explicit Ver.)                   0.528567
# LALA                                                  0.380635
# vampire                                               0.685082
# Cruel Summer                                          0.604323
# WHERE SHE GOES                                        0.529490
#
# track_name                           A Veces (feat. Feid)  En La De Ella  \
# track_name
# Seven (feat. Latto) (Explicit Ver.)              0.970908       0.974293
# LALA                                             0.984703       0.997566
# vampire                                          0.804157       0.850583
# Cruel Summer                                     0.850565       0.871277
# WHERE SHE GOES                                   0.702161       0.759296
#
# track_name                              Alone
# track_name
# Seven (feat. Latto) (Explicit Ver.)  0.943181
# LALA                                 0.970845
# vampire                              0.881730
# Cruel Summer                         0.871340
# WHERE SHE GOES                       0.812195
#
# [5 rows x 953 columns]

# %%
similarity_df.shape
# Out:
# (953, 953)

# %% [markdown]
# Based on song

# %%
def get_song_recommendations(song_name, num_recommendations=5):
    """
    Get song recommendations based on a given song.

    Parameters:
    - song_name: Name of the song provided by the user.
    - num_recommendations: Number of songs to recommend (default is 5).

    Returns:
    - List of recommended songs.
    """
    # Check if the song is in our dataset
    if song_name not in similarity_df.index:
        return "Sorry, the song was not found in the dataset."

    # Get the similarity values for the given song
    song_similarities = similarity_df[song_name].sort_values(ascending=False)

    # Get the most similar songs (excluding the input song itself)
    recommended_songs = song_similarities.iloc[1:num_recommendations+1].index.tolist()

    return recommended_songs

# Test the function with a sample song
sample_song = "I Wanna Be Yours"
test_recommendations = get_song_recommendations(sample_song, 10)
test_recommendations
# Out:
# ['Mejor Que Yo',
#  'No Se Va',
#  'Ferxxo 100',
#  'Grapejuice',
#  'Volando - Remix',
#  'Leave The Door Open',
#  'Come Back Home - From "Purple Hearts"',
#  "she's all i wanna be",
#  'Di Que Si',
#  'WANDA']

# %% [markdown]
# ### Save similarity matrix as csv file

# %%
similarity_df.to_csv('similarity_df.csv', index=True)

# %%
similarity_df
# Out:
# track_name                           Seven (feat. Latto) (Explicit Ver.)  \
# track_name
# Seven (feat. Latto) (Explicit Ver.)                             1.000000
# LALA                                                            0.975647
# vampire                                                         0.880344
# Cruel Summer                                                    0.913981
# WHERE SHE GOES                                                  0.755991
# ...                                                                  ...
# My Mind & Me                                                    0.805591
# Bigger Than The Whole Sky                                       0.528567
# A Veces (feat. Feid)                                            0.970908
# En La De Ella                                                   0.974293
# Alone                                                           0.943181
#
# track_name                               LALA   vampire  Cruel Summer  \
# track_name
# Seven (feat. Latto) (Explicit Ver.)  0.975647  0.880344      0.913981
# LALA                                 1.000000  0.848438      0.876134
# vampire                              0.848438  1.000000      0.947706
# Cruel Summer                         0.876134  0.947706      1.000000
# WHERE SHE GOES                       0.761163  0.808084      0.800570
# ...                                       ...       ...           ...
# My Mind & Me                         0.707324  0.860803      0.808021
# Bigger Than The Whole Sky            0.380635  0.685082      0.604323
# A Veces (feat. Feid)                 0.984703  0.804157      0.850565
# En La De Ella                        0.997566  0.850583      0.871277
# Alone                                0.970845  0.881730      0.871340
#
# track_name                           WHERE SHE GOES  Sprinter  \
# track_name
# Seven (feat. Latto) (Explicit Ver.)        0.755991  0.936269
# LALA                                       0.761163  0.916185
# vampire                                    0.808084  0.877307
# Cruel Summer                               0.800570  0.910577
# WHERE SHE GOES                             1.000000  0.753580
# ...                                             ...       ...
# My Mind & Me                               0.717606  0.820281
# Bigger Than The Whole Sky                  0.529490  0.558631
# A Veces (feat. Feid)                       0.702161  0.928006
# En La De Ella                              0.759296  0.933421
# Alone                                      0.812195  0.896686
#
# track_name                           Ella Baila Sola  Columbia  fukumean  \
# track_name
# Seven (feat. Latto) (Explicit Ver.)         0.979482  0.910542  0.855850
# LALA                                        0.917155  0.908580  0.876697
# vampire                                     0.905297  0.879835  0.919387
# Cruel Summer                                0.931923  0.837759  0.855452
# WHERE SHE GOES                              0.754172  0.806952  0.811049
# ...                                              ...       ...       ...
# My Mind & Me                                0.877326  0.872293  0.822830
# Bigger Than The Whole Sky                   0.665652  0.645065  0.572939
# A Veces (feat. Feid)                        0.905283  0.847442  0.837234
# En La De Ella                               0.913442  0.908928  0.894846
# Alone                                       0.901702  0.973997  0.924033
#
# track_name                           La Bebe - Remix  ...  Privileged Rappers  \
# track_name                                            ...
# Seven (feat. Latto) (Explicit Ver.)         0.865533  ...            0.921663
# LALA                                        0.819718  ...            0.924463
# vampire                                     0.880600  ...            0.881834
# Cruel Summer                                0.922431  ...            0.913622
# WHERE SHE GOES                              0.736370  ...            0.765912
# ...                                              ...  ...                 ...
# My Mind & Me                                0.836975  ...            0.766308
# Bigger Than The Whole Sky                   0.642219  ...            0.477775
# A Veces (feat. Feid)                        0.830181  ...            0.932713
# En La De Ella                               0.838514  ...            0.941449
# Alone                                       0.815200  ...            0.898422
#
# track_name                           The Astronaut  BackOutsideBoyz  \
# track_name
# Seven (feat. Latto) (Explicit Ver.)       0.858991         0.796932
# LALA                                      0.890907         0.798221
# vampire                                   0.918433         0.875415
# Cruel Summer                              0.914379         0.844334
# WHERE SHE GOES                            0.847082         0.707696
# ...                                            ...              ...
# My Mind & Me                              0.734772         0.739995
# Bigger Than The Whole Sky                 0.485726         0.522500
# A Veces (feat. Feid)                      0.815500         0.803470
# En La De Ella                             0.881411         0.824655
# Alone                                     0.938267         0.803582
#
# track_name                           Broke Boys  The Great War  My Mind & Me  \
# track_name
# Seven (feat. Latto) (Explicit Ver.)    0.741030       0.981515      0.805591
# LALA                                   0.775496       0.978372      0.707324
# vampire                                0.865885       0.873215      0.860803
# Cruel Summer                           0.835299       0.899534      0.808021
# WHERE SHE GOES                         0.764178       0.775037      0.717606
# ...                                         ...            ...           ...
# My Mind & Me                           0.708671       0.770482      1.000000
# Bigger Than The Whole Sky              0.505006       0.495605      0.914068
# A Veces (feat. Feid)                   0.730533       0.945626      0.673992
# En La De Ella                          0.790442       0.967469      0.721053
# Alone                                  0.838653       0.972274      0.775934
#
# track_name                           Bigger Than The Whole Sky  \
# track_name
# Seven (feat. Latto) (Explicit Ver.)                   0.528567
# LALA                                                  0.380635
# vampire                                               0.685082
# Cruel Summer                                          0.604323
# WHERE SHE GOES                                        0.529490
# ...                                                        ...
# My Mind & Me                                          0.914068
# Bigger Than The Whole Sky                             1.000000
# A Veces (feat. Feid)                                  0.337681
# En La De Ella                                         0.392244
# Alone                                                 0.488695
#
# track_name                           A Veces (feat. Feid)  En La De Ella  \
# track_name
# Seven (feat. Latto) (Explicit Ver.)              0.970908       0.974293
# LALA                                             0.984703       0.997566
# vampire                                          0.804157       0.850583
# Cruel Summer                                     0.850565       0.871277
# WHERE SHE GOES                                   0.702161       0.759296
# ...                                                   ...            ...
# My Mind & Me                                     0.673992       0.721053
# Bigger Than The Whole Sky                        0.337681       0.392244
# A Veces (feat. Feid)                             1.000000       0.988365
# En La De Ella                                    0.988365       1.000000
# Alone                                            0.920664       0.967555
#
# track_name                              Alone
# track_name
# Seven (feat. Latto) (Explicit Ver.)  0.943181
# LALA                                 0.970845
# vampire                              0.881730
# Cruel Summer                         0.871340
# WHERE SHE GOES                       0.812195
# ...                                       ...
# My Mind & Me                         0.775934
# Bigger Than The Whole Sky            0.488695
# A Veces (feat. Feid)                 0.920664
# En La De Ella                        0.967555
# Alone                                1.000000
#
# [953 rows x 953 columns]

# %%
####################################################

# %%
spotify_data.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# 0                147  141381703                  43  ...  125   B  Major
# 1                 48  133716286                  48  ...   92  C#  Major
# 2                113  140003974                  94  ...  138   F  Major
# 3                100  800840817                 116  ...  170   A  Major
# 4                 50  303236322                  84  ...  144   A  Minor
#
#   danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 0             80         89       83             31                   0
# 1             71         61       74              7                   0
# 2             51         32       53             17                   0
# 3             55         58       72             11                   0
# 4             65         23       80             14                  63
#
#    liveness_%  speechiness_%
# 0           8              4
# 1          10              4
# 2          31              6
# 3          11             15
# 4          11              6
#
# [5 rows x 24 columns]

# %%
spotify_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
#  15  key                   858 non-null    object
#  16  mode                  953 non-null    object
#  17  danceability_%        953 non-null    int64
#  18  valence_%             953 non-null    int64
#  19  energy_%              953 non-null    int64
#  20  acousticness_%        953 non-null    int64
#  21  instrumentalness_%    953 non-null    int64
#  22  liveness_%            953 non-null    int64
#  23  speechiness_%         953 non-null    int64
# dtypes: int64(17), object(7)
# memory usage: 178.8+ KB

# %%
spotify_data['streams_M'] = pd.to_numeric(spotify_data['streams'], errors='coerce')

# %%
spotify_data['streams_M'] = spotify_data['streams_M'] / 1000000

# %%
spotify_data['streams_M'] = spotify_data['streams_M'].round(3)

# %%
spotify_data.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  key   mode  \
# 0                147  141381703                  43  ...    B  Major
# 1                 48  133716286                  48  ...   C#  Major
# 2                113  140003974                  94  ...    F  Major
# 3                100  800840817                 116  ...    A  Major
# 4                 50  303236322                  84  ...    A  Minor
#
#    danceability_% valence_%  energy_% acousticness_% instrumentalness_%  \
# 0              80        89        83             31                  0
# 1              71        61        74              7                  0
# 2              51        32        53             17                  0
# 3              55        58        72             11                  0
# 4              65        23        80             14                 63
#
#    liveness_%  speechiness_%  streams_M
# 0           8              4    141.382
# 1          10              4    133.716
# 2          31              6    140.004
# 3          11             15    800.841
# 4          11              6    303.236
#
# [5 rows x 25 columns]
